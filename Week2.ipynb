# %% [markdown]
# <a href="https://colab.research.google.com/github/reyhansyamsudin/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Reyhan Syamsudin
#
# Kelas: TI - 3G / 27
#
# NIM  : 1941720210

# %% [markdown]
# **D. PRAKTIKUM**
#
# Buka https://colab.research.google.com/. Setelah dipastikan bahwa google Colab terhubung dengan Github Anda, lanjutkan dengan memilih repository yang telah digunakan pada praktikum minggu lalu, rename file menjadi “Week2.ipynb”.
# Kemudian import folder yang ada di Drive Anda dengan cara sebagai berikut.

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Jika berhasil, maka Google Colab sudah dapat mengakses folder gdrive Anda dengan keterangan output program “Mounted at /content/drive”
#
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# *   Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# *   Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# *   Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# *   Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# *   Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
cv.circle(black_img,center=(400,400),radius=20,color=(255,0,0),thickness=70)
plt.imshow(black_img)

# %% [markdown]
# *   Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# *   Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tpe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# *   Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# *   Penambahan polyline pada black image kedua yang telah dibuat

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN** :
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#    **Jawab**: Dari percobaan praktikum diatas Matplotlib yaitu untuk mengetahui ukuran panjang dan lebar, dari gambar tersebut.  jika tidak menggunakan plot matplotlib maka tidak dapat mengetahui ukurannya.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
#   **Jawab**: Perbedaanya adalah ukuran dan kepekatan data
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2)) pts = vertices.reshape((-1,1,2))
#
#    **Jawab:** perbedaannya hanya  menjadi 2 kolom dan ada jarak pada setiap angka
#
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut from google.colab.patches import cv2_imshow from skimage import io
#
#   **Jawab:** yaitu untuk membaca, menampilkan, dan mengkonversi ke hitam putih sebuah citra dengan menambakan satu patches karena cv.imsow tidak berjalan di google colab maupun Jupyter Notebook
#
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
#    **Jawab:** pemrosesan gambar atau menampilkan gambar

# %% [markdown]
# **E. Tugas**
#
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
#
# 2. Tampilkan image baris ke 10-100, kolom 10-100!
#
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
#
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
#
# 5. Tampilkan image dengan posisi terbalik!
#
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
#
#
# 1. Buat rectangle dan circle pada bagian wajah dari image kitten!
#
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
#
# 3. Tunjukkan code program anda pada bapak/ibu dosen
#
#                                    ** Jawab **
# 1.Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
plt.imshow(img_gray, cmap='RdYlGn')

# %%
plt.imshow(img_gray, cmap='GnBu')

# %% [markdown]
# 1. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %% [markdown]
# 2. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(img[5:30])

# %% [markdown]
# 3. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
cv.rectangle(img3,pt1=(40,40),pt2=(234,867),color=(104,58,208),thickness=15)
cv.rectangle(img3,pt1=(654,34),pt2=(45,424),color=(37,20,74),thickness=15)
cv.rectangle(img3,pt1=(450,303),pt2=(79,121),color=(14,105,102),thickness=15)
cv.rectangle(img3,pt1=(343,98),pt2=(654,454),color=(246,25,97),thickness=15)
cv.rectangle(img3,pt1=(50,67),pt2=(753,866),color=(123,12,48),thickness=15)
plt.imshow(img3)

# %% [markdown]
# 4. Tampilkan image dengan posisi terbalik!

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 5. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
img2 = img
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img7,pt1=(290,70),pt2=(480,240),color=(164,94,126),thickness=12)
cv.circle(img7,center=(390,155),radius=100,color=(65,37,50),thickness=12)
plt.imshow(img7)

# %% [markdown]
# 6. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!

# %%
img2 = img
img2 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img2,pt1=(100,500),pt2=(10,620),color=(37,50,65),thickness=15)
plt.imshow(img2)
